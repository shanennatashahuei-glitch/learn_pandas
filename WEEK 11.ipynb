# %% [markdown]
# PANDAS 41

# %% [markdown]
# #41: Agregasi pada banyak kolom Data Frame dengan agg()

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
df = pd.read_csv('titanicfull.csv')
df.head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                1             Allison, Mr. Hudson Joshua Creighton
# 4       1                1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       Sex    Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %%
df.groupby('Pclass').agg({
    'Pclass': 'count',
    'Age': ['mean', 'max'],
    'Survival status': 'mean'
})
# Out:
#        Pclass     Age       Survival status
#         count    mean   max            mean
# Pclass
# 1           5  17.384  30.0             0.8

# %%
df.groupby('Pclass').agg(
    n_pass=('Pclass', 'count'),
    avg_age=('Age', 'mean'),
    max_age=('Age', 'max'), 
    survival_rate=('Survival status', 'mean')
)
# Out:
#         n_pass  avg_age  max_age  survival_rate
# Pclass
# 1            5   17.384     30.0            0.8

# %% [markdown]
# PANDAS 42

# %% [markdown]
# #42: Mengurutkan data kolom pada Data Frame

# %%
df = pd.read_csv('titanicfull.csv')
df.head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                1             Allison, Mr. Hudson Joshua Creighton
# 4       1                1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       Sex    Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %%
df.sort_values('Age').head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 4       1                1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 3       1                1             Allison, Mr. Hudson Joshua Creighton
#
#       Sex    Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S

# %%
df.sort_values('Age', ascending=False).head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 3       1                1             Allison, Mr. Hudson Joshua Creighton
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 4       1                1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 2       1                0                     Allison, Miss. Helen Loraine
# 1       1                1                   Allison, Master. Hudson Trevor
#
#       Sex    Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S

# %%
df.sort_values(['Survival status', 'Age']).head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 2       1                0                     Allison, Miss. Helen Loraine
# 1       1                1                   Allison, Master. Hudson Trevor
# 4       1                1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 3       1                1             Allison, Mr. Hudson Joshua Creighton
#
#       Sex    Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S

# %% [markdown]
# PANDAS 43

# %% [markdown]
# #43: Menangani whitespace pada Pandas Data Frame

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %%
data = {'nim': ['10', '11', '12', '13', '  '],
        'nama': ['adi', '  ', 'tejo', '  ', 'bejo']}

df = pd.DataFrame(data)
df
# Out:
#   nim  nama
# 0  10   adi
# 1  11
# 2  12  tejo
# 3  13
# 4      bejo

# %%
df
# Out:
#   nim  nama
# 0  10   adi
# 1  11
# 2  12  tejo
# 3  13
# 4      bejo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nim     5 non-null      object
#  1   nama    5 non-null      object
# dtypes: object(2)
# memory usage: 212.0+ bytes

# %%
df = df.replace(r'^\s*$', np.nan, regex=True)
df
# Out:
#    nim  nama
# 0   10   adi
# 1   11   NaN
# 2   12  tejo
# 3   13   NaN
# 4  NaN  bejo

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nim     4 non-null      object
#  1   nama    3 non-null      object
# dtypes: object(2)
# memory usage: 212.0+ bytes

# %% [markdown]
# PANDAS 44

# %% [markdown]
# #44: Menata ulan kolom Data Frame

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')
df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  2  3  4  2  2
# 1  1  1  6  9  5
# 2  2  1  6  1  4
# 3  9  6  8  7  6
# 4  3  9  9  9  7

# %%
df[['D', 'C', 'A', 'E', 'B']]
# Out:
#    D  C  A  E  B
# 0  2  4  2  2  3
# 1  9  6  1  5  1
# 2  1  6  2  4  1
# 3  7  8  9  6  6
# 4  9  9  3  7  9

# %%
df
# Out:
#    A  B  C  D  E
# 0  2  3  4  2  2
# 1  1  1  6  9  5
# 2  2  1  6  1  4
# 3  9  6  8  7  6
# 4  3  9  9  9  7

# %%
df = df[['D', 'C', 'A', 'E', 'B']]
df
# Out:
#    D  C  A  E  B
# 0  2  4  2  2  3
# 1  9  6  1  5  1
# 2  1  6  2  4  1
# 3  7  8  9  6  6
# 4  9  9  3  7  9
