# %% [markdown]
# PANDAS 45

# %% [markdown]
# #45: Memadukan loc dan iloc untuk seleksi data pada Data Frame

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
df = pd.read_csv('titanicfull.csv')
df.head()
# Out:
#    Pclass  Survival status                                        full Name  \
# 0       1                1                    Allen, Miss. Elisabeth Walton
# 1       1                1                   Allison, Master. Hudson Trevor
# 2       1                0                     Allison, Miss. Helen Loraine
# 3       1                1             Allison, Mr. Hudson Joshua Creighton
# 4       1                1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       Sex    Age  Sib SP  Parch  Ticket      Fare    Cabin Embarked
# 0  female  29.00       0      0   24160  211.3375       B5        S
# 1    male   0.92       1      2  113781  151.5500  C22 C26        S
# 2  female   2.00       1      2  113781  151.5500  C22 C26        S
# 3    male  30.00       1      2  113781  151.5500  C22 C26        S
# 4  female  25.00       1      2  113781  151.5500  C22 C26        S

# %%
df.iloc[15:20, :].loc[:, 'full Name':'Age']
# Out:
# Empty DataFrame
# Columns: [full Name, Sex, Age]
# Index: []

# %%
df.loc[:, 'full Name':'Age'].iloc[15:20, :]
# Out:
# Empty DataFrame
# Columns: [full Name, Sex, Age]
# Index: []

# %% [markdown]
# PANDAS 46

# %% [markdown]
# #46: Seleksi weekdays dan weekends pada data deret waktu

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.5

# %%
n_rows = 365
n_cols = 2
cols = ['col1', 'col2']

df = pd.DataFrame(np.random.randint(1, 20, size=(n_rows, n_cols)), columns=cols)

df.index = pd.date_range(start='2024-01-01', periods=n_rows, freq='D')
print(df)
# Out:
#             col1  col2
# 2024-01-01    18     4
# 2024-01-02    11    16
# 2024-01-03    17     1
# 2024-01-04     4    16
# 2024-01-05    16    17
# ...          ...   ...
# 2024-12-26    19    15
# 2024-12-27     8     3
# 2024-12-28    10     2
# 2024-12-29    15    15
# 2024-12-30    13     9
#
# [365 rows x 2 columns]

# %% [markdown]
# Seleksi weekdays dan weekends

# %%
weekdays_df = df[df.index.dayofweek.isin([0, 1, 2, 3, 4])]
weekdays_df.head(7)
# Out:
#             col1  col2
# 2024-01-01    18     4
# 2024-01-02    11    16
# 2024-01-03    17     1
# 2024-01-04     4    16
# 2024-01-05    16    17
# 2024-01-08     9     2
# 2024-01-09     4     7

# %%
weekends_df = df[df.index.dayofweek.isin([5, 6])]
weekends_df.head(7)
# Out:
#             col1  col2
# 2024-01-06    15    15
# 2024-01-07     8    16
# 2024-01-13    16    17
# 2024-01-14    10     9
# 2024-01-20     3     7
# 2024-01-21    19     8
# 2024-01-27    16    11

# %% [markdown]
# PANDAS 47

# %% [markdown]
# #47: Penanganan kolom dengan tipe data beragam

# %%
d = {'nama':['bejo', 'tejo', 'wati', 'tiwi', 'cecep'], 
     'ipk':[2, '3', 3, 2.75, '3.25']}
df = pd.DataFrame(d)
df
# Out:
#     nama   ipk
# 0   bejo     2
# 1   tejo     3
# 2   wati     3
# 3   tiwi  2.75
# 4  cecep  3.25

# %%
df.dtypes
# Out:
# nama    object
# ipk     object
# dtype: object

# %%
df['ipk'].apply(type)
# Out:
# 0      <class 'int'>
# 1      <class 'str'>
# 2      <class 'int'>
# 3    <class 'float'>
# 4      <class 'str'>
# Name: ipk, dtype: object

# %%
df['ipk'].apply(type).value_counts()
# Out:
# ipk
# <class 'int'>      2
# <class 'str'>      2
# <class 'float'>    1
# Name: count, dtype: int64

# %%
df['ipk'] = df['ipk'].astype(float)

# %%
df['ipk'].apply(type).value_counts()
# Out:
# ipk
# <class 'float'>    5
# Name: count, dtype: int64

# %% [markdown]
# PANDAS 48

# %% [markdown]
# #48: Cummulative Count pada Pandas Data Frame

# %%
d = {'penjual':['bejo', 'shanen', 'wati', 'bejo', 'cecep', 'shanen', 'wati', 'bejo'], 
     'barang':['monitor', 'monitor', 'keyboard', 'mouse', 'keyboard', 'monitor', 'laptop', 'monitor']}

df = pd.DataFrame(d)
df
# Out:
#   penjual    barang
# 0    bejo   monitor
# 1  shanen   monitor
# 2    wati  keyboard
# 3    bejo     mouse
# 4   cecep  keyboard
# 5  shanen   monitor
# 6    wati    laptop
# 7    bejo   monitor

# %% [markdown]
# Mengenal Cummulative Count dengan cumcount()

# %%
df['count_tiap_penjual'] = df.groupby('penjual').cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual
# 0    bejo   monitor                   1
# 1  shanen   monitor                   1
# 2    wati  keyboard                   1
# 3    bejo     mouse                   2
# 4   cecep  keyboard                   1
# 5  shanen   monitor                   2
# 6    wati    laptop                   2
# 7    bejo   monitor                   3

# %%
df['count_tiap_barang'] = df.groupby('barang').cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual  count_tiap_barang
# 0    bejo   monitor                   1                  1
# 1  shanen   monitor                   1                  2
# 2    wati  keyboard                   1                  1
# 3    bejo     mouse                   2                  1
# 4   cecep  keyboard                   1                  2
# 5  shanen   monitor                   2                  3
# 6    wati    laptop                   2                  1
# 7    bejo   monitor                   3                  4

# %%
df['count_pasangan_kolom'] = df.groupby(['penjual', 'barang']).cumcount() + 1
df
# Out:
#   penjual    barang  count_tiap_penjual  count_tiap_barang  \
# 0    bejo   monitor                   1                  1
# 1  shanen   monitor                   1                  2
# 2    wati  keyboard                   1                  1
# 3    bejo     mouse                   2                  1
# 4   cecep  keyboard                   1                  2
# 5  shanen   monitor                   2                  3
# 6    wati    laptop                   2                  1
# 7    bejo   monitor                   3                  4
#
#    count_pasangan_kolom
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# 5                     2
# 6                     1
# 7                     2
